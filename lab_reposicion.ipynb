# %% [markdown]
# # Laboratorio de Reposicion
# ##### Oscar Fernando Lopez Barrios
# ##### Carne 20679

# %%
# Importacion de las librerias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('framingham.csv')
data
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
# Se imprime la data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3657 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             3657 non-null   int64
#  1   age              3657 non-null   int64
#  2   education        3657 non-null   float64
#  3   currentSmoker    3657 non-null   int64
#  4   cigsPerDay       3657 non-null   float64
#  5   BPMeds           3657 non-null   float64
#  6   prevalentStroke  3657 non-null   int64
#  7   prevalentHyp     3657 non-null   int64
#  8   diabetes         3657 non-null   int64
#  9   totChol          3657 non-null   float64
#  10  sysBP            3657 non-null   float64
#  11  diaBP            3657 non-null   float64
#  12  BMI              3657 non-null   float64
#  13  heartRate        3656 non-null   float64
#  14  glucose          3657 non-null   float64
#  15  TenYearCHD       3657 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
# Se muestra el mapa para conocer los datos vacios
sns.heatmap(data.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')

# %%
# Dropear los datos con NA
data.dropna(subset = ['education'], inplace = True)
data.dropna(subset = ['cigsPerDay'], inplace = True)
data.dropna(subset = ['BPMeds'], inplace = True)
data.dropna(subset = ['totChol'], inplace = True)
data.dropna(subset = ['BMI'], inplace = True)
data.dropna(subset = ['glucose'], inplace = True)

# %%
# Se muestra el mapa para conocer los datos vacios
sns.heatmap(data.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
